# %%
import pandas as pd

# %%
df = pd.read_csv('airports.csv')
df = df[df['type']  != 'heliport']

# %%
df.head()
# Out:
#                                name iso_country     municipality iata_code
# 1438           Loring Seaplane Base          US           Loring       WLR
# 1574       Port Alice Seaplane Base          US       Port Alice       PTC
# 1758  Port Protection Seaplane Base          US  Port Protection       PPV
# 2383          Ellamar Seaplane Base          US          Ellamar       ELW
# 3642  Entrance Island Seaplane Base          US  Entrance Island       HBH

# %%
df = pd.read_csv('airports.csv')

# %%
df['type'].unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
df = df[df['type']  != 'heliport']
df = df[df['type']  != 'small_airport']
df = df[df['type']  != 'closed']
df = df[df['type']  != 'balloonport']

# %%
# Out:
#     ident           type                            name  elevation_ft  \
# 36   00NK  seaplane_base       Cliche Cove Seaplane Base          96.0
# 93   01MD  seaplane_base         Annapolis Seaplane Base           NaN
# 94   01ME  seaplane_base     Saint Peter's Seaplane Base         608.0
# 96   01MN  seaplane_base            Barnes Seaplane Base        1358.0
# 163  02NH  seaplane_base  Iroquois Landing Seaplane Base        1180.0
#
#     continent iso_country iso_region  municipality gps_code iata_code  \
# 36        NaN          US      US-NY   Beekmantown     00NK       NaN
# 93        NaN          US      US-MD     Annapolis     01MD       NaN
# 94        NaN          US      US-ME  Portage Lake     01ME       NaN
# 96        NaN          US      US-MN          Cook     01MN       NaN
# 163       NaN          US      US-NH        Dummer     02NH       NaN
#
#     local_code                             coordinates
# 36        00NK                 44.8118612, -73.3698057
# ...

# %%
df = df[~df.iata_code.isna()]

# %%
df.drop('type', inplace=True, axis=1)
df.drop('ident', inplace=True, axis=1)
df.drop('elevation_ft', inplace=True, axis=1)
df.drop('continent', inplace=True, axis=1)
df.drop('iso_region', inplace=True, axis=1)
df.drop('gps_code', inplace=True, axis=1)
df.drop('local_code', inplace=True, axis=1)
df.drop('coordinates', inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-146-249fc98680e9> in <module>
# ----> 1 df.drop('type', inplace=True, axis=1)
#       2 df.drop('ident', inplace=True, axis=1)
#       3 df.drop('elevation_ft', inplace=True, axis=1)
#       4 df.drop('continent', inplace=True, axis=1)
#       5 df.drop('iso_region', inplace=True, axis=1)
#
# ~\AppData\Local\Continuum\anaconda3\envs\myEnv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4095             level=level,
#    4096             inplace=inplace,
# -> 4097             errors=errors,
#    4098         )
#    4099
#
# ~\AppData\Local\Continuum\anaconda3\envs\myEnv\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3913         for axis, labels in axes.items():
# ...

# %%
df.to_csv('airports_simple.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                           name iso_country     municipality  \
# 0        1438           Loring Seaplane Base          US           Loring
# 1        1574       Port Alice Seaplane Base          US       Port Alice
# 2        1758  Port Protection Seaplane Base          US  Port Protection
# 3        2383          Ellamar Seaplane Base          US          Ellamar
# 4        3642  Entrance Island Seaplane Base          US  Entrance Island
#
#   iata_code
# 0       WLR
# 1       PTC
# 2       PPV
# 3       ELW
# 4       HBH

# %%
df = pd.read_csv('airports_simple.csv')

# %%
df = df[~df.municipality.isna()]

# %%
df
# Out:
#       Unnamed: 0                           name iso_country     municipality  \
# 0           1438           Loring Seaplane Base          US           Loring
# 1           1574       Port Alice Seaplane Base          US       Port Alice
# 2           1758  Port Protection Seaplane Base          US  Port Protection
# 3           2383          Ellamar Seaplane Base          US          Ellamar
# 4           3642  Entrance Island Seaplane Base          US  Entrance Island
# ...          ...                            ...         ...              ...
# 4597       55104             Zhoushuizi Airport          CN           Dalian
# 4598       55105      Tonghua Sanyuanpu Airport          CN          Tonghua
# 4599       55106                Taoxian Airport          CN         Shenyang
# 4600       55107    Yanji Chaoyangchuan Airport          CN            Yanji
# 4601       55108          Yingkou Lanqi Airport          CN          Yingkou
#
#      iata_code
# 0          WLR
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-4656dd9bd29c> in <module>
# ----> 1 df.drop('type', inplace=True, axis=1)
#       2 df.drop('ident', inplace=True, axis=1)
#       3 df.drop('ident', inplace=True, axis=1)
#       4 df.drop('ident', inplace=True, axis=1)
#
# ~\AppData\Local\Continuum\anaconda3\envs\myEnv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4095             level=level,
#    4096             inplace=inplace,
# -> 4097             errors=errors,
#    4098         )
#    4099
#
# ~\AppData\Local\Continuum\anaconda3\envs\myEnv\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3913         for axis, labels in axes.items():
#    3914             if labels is not None:
# ...

# %%
df = df[df['type'] != 'balloonport']

# %%
df.drop('ident', axis=1, inplace=True)

# %%
df.drop('local_code', axis=1, inplace=True)

# %%
df.type.unique().count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-462035f3c688> in <module>
# ----> 1 df.type.unique().count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
df = df[df['type'] != 'small_airport']

# %%
df.shape
# Out:
# (5144, 7)

# %%
pd.read_csv('airports_simple.csv')
# Out:
#       Unnamed: 0                                                  x
# 0           6187  Aleknagik / New Airport,Aleknagik / New Airpor...
# 1          10435  Honiara International Airport,Honiara Internat...
# 2          10440                   Munda Airport,Munda Airport(MUA)
# 3          10462             Hongyuan Airport,Hongyuan Airport(AHJ)
# 4          10686  Nauru International Airport,Nauru Internationa...
# ...          ...                                                ...
# 4453       55104         Zhoushuizi Airport,Zhoushuizi Airport(DLC)
# 4454       55105  Tonghua Sanyuanpu Airport,Tonghua Sanyuanpu Ai...
# 4455       55106               Taoxian Airport,Taoxian Airport(SHE)
# 4456       55107  Yanji Chaoyangchuan Airport,Yanji Chaoyangchua...
# 4457       55108   Yingkou Lanqi Airport,Yingkou Lanqi Airport(YKH)
#
# [4458 rows x 2 columns]

# %%
df.head()
# Out:
#                  type                           name continent iso_country  \
# 6187   medium_airport        Aleknagik / New Airport       NaN          US
# 10435  medium_airport  Honiara International Airport        OC          SB
# 10440  medium_airport                  Munda Airport        OC          SB
# 10462  medium_airport               Hongyuan Airport        AS          CN
# 10686  medium_airport    Nauru International Airport        OC          NR
#
#       iso_region iata_code                             coordinates
# 6187       US-AK       WKK           59.2826004028, -158.617996216
# 10435      SB-CT       HIR       -9.4280004501343, 160.05499267578
# 10440      SB-WE       MUA  -8.327969551086426, 157.26300048828125
# 10462      CN-51       AHJ                     32.53154, 102.35224
# 10686      NR-14       INU                   -0.547458, 166.919006

# %%
df.drop('coordinates', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                 name iso_country iata_code
# 6187         Aleknagik / New Airport          US       WKK
# 10435  Honiara International Airport          SB       HIR
# 10440                  Munda Airport          SB       MUA
# 10462               Hongyuan Airport          CN       AHJ
# 10686    Nauru International Airport          NR       INU

# %%
df.to_csv('airports_conc.csv')

# %%
df.describe()
# Out:
#                      name iso_country iata_code
# count                5144        5132      4458
# unique               5125         235      4452
# top     Newcastle Airport          US       JNB
# freq                    3         858         3

# %%
df['x'] = df['name'] + ',' + df['name'] + '(' + df['iata_code'] +  ')'
# Out:
# C:\Users\SG0216333\AppData\Local\Continuum\anaconda3\envs\myEnv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.drop('name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-fafbc99a4716> in <module>
# ----> 1 df.drop('name')
#
# ~\AppData\Local\Continuum\anaconda3\envs\myEnv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4095             level=level,
#    4096             inplace=inplace,
# -> 4097             errors=errors,
#    4098         )
#    4099
#
# ~\AppData\Local\Continuum\anaconda3\envs\myEnv\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3913         for axis, labels in axes.items():
#    3914             if labels is not None:
# -> 3915                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3916
#    3917         if inplace:
#
# ...

# %%
df.drop('iata_code', axis=1, inplace=True)

# %%
d

# %%
df.head()
# Out:
#                                                        x
# 6187   Aleknagik / New Airport,Aleknagik / New Airpor...
# 10435  Honiara International Airport,Honiara Internat...
# 10440                   Munda Airport,Munda Airport(MUA)
# 10462             Hongyuan Airport,Hongyuan Airport(AHJ)
# 10686  Nauru International Airport,Nauru Internationa...

# %%
x= pd.read_csv('airports_conc.csv')

# %%
x.head()
# Out:
#    Unnamed: 0                                                  x
# 0        6187  Aleknagik / New Airport,Aleknagik / New Airpor...
# 1       10435  Honiara International Airport,Honiara Internat...
# 2       10440                   Munda Airport,Munda Airport(MUA)
# 3       10462             Hongyuan Airport,Hongyuan Airport(AHJ)
# 4       10686  Nauru International Airport,Nauru Internationa...

# %%
x[~x['x'].isna()].to_csv('airports_conc.csv')

# %%
df[~df['x'].isna()].to_csv('airports_simple.csv')

# %%
pd.read_csv('airports_simple.csv')
# Out:
#       Unnamed: 0                                                  x
# 0           6187  Aleknagik / New Airport,Aleknagik / New Airpor...
# 1          10435  Honiara International Airport,Honiara Internat...
# 2          10440                   Munda Airport,Munda Airport(MUA)
# 3          10462             Hongyuan Airport,Hongyuan Airport(AHJ)
# 4          10686  Nauru International Airport,Nauru Internationa...
# ...          ...                                                ...
# 4453       55104         Zhoushuizi Airport,Zhoushuizi Airport(DLC)
# 4454       55105  Tonghua Sanyuanpu Airport,Tonghua Sanyuanpu Ai...
# 4455       55106               Taoxian Airport,Taoxian Airport(SHE)
# 4456       55107  Yanji Chaoyangchuan Airport,Yanji Chaoyangchua...
# 4457       55108   Yingkou Lanqi Airport,Yingkou Lanqi Airport(YKH)
#
# [4458 rows x 2 columns]

# %%
df['x'].head()
# Out:
# 6187           Aleknagik / New Airport,
# 10435    Honiara International Airport,
# 10440                    Munda Airport,
# 10462                 Hongyuan Airport,
# 10686      Nauru International Airport,
# Name: x, dtype: object

# %%
def contains_(text='New'):
    return df[df['name'].str.contains(text, regex=False)]

print (contains_())
# Out:
#                                                     name iso_country iata_code
# 6187                             Aleknagik / New Airport          US       WKK
# 15206                              Nanchang New Airfield          CN       NaN
# 18530                           Newquay Cornwall Airport          GB       NQY
# 18587                                  Newcastle Airport          GB       NCL
# 20015                                  Newcastle Airport          ZA       NCS
# 23163                                 Merowe New Airport          SD       MWE
# 23173               Port Sudan New International Airport          SD       PZU
# 24266                                    H1 New Air Base          IQ       NaN
# 24300                            Tal Ashtah New Air Base          IQ       NaN
# 24304                         Wadi Al Khirr New Air Base          IQ       NaN
# 24411                               New Ishigaki Airport          JP       ISG
# ...

# %%
df = df[df['type'] != 'balloonport']

# %%
df = pd.read_csv('airports.csv')

# %%
df.head()
# Out:
#                  type                           name iso_country iata_code
# 6187   medium_airport        Aleknagik / New Airport          US       WKK
# 10435  medium_airport  Honiara International Airport          SB       HIR
# 10440  medium_airport                  Munda Airport          SB       MUA
# 10462  medium_airport               Hongyuan Airport          CN       AHJ
# 10686  medium_airport    Nauru International Airport          NR       INU

# %%
df.drop('ident', inplace=True, axis=1)

# %%
df.drop('coordinates', inplace=True, axis=1)

# %%
df = df[df['type'] != 'balloonport']

# %%
df['type'].unique()
# Out:
# array(['medium_airport', 'large_airport'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9177 entries, 223 to 55108
# Data columns (total 12 columns):
# ident           9177 non-null object
# type            9177 non-null object
# name            9177 non-null object
# elevation_ft    8826 non-null float64
# continent       6200 non-null object
# iso_country     9146 non-null object
# iso_region      9177 non-null object
# municipality    8416 non-null object
# gps_code        8543 non-null object
# iata_code       9177 non-null object
# local_code      3002 non-null object
# coordinates     9177 non-null object
# dtypes: float64(1), object(11)
# memory usage: 932.0+ KB

# %%
df = df[~df.iata_code.isna()]

# %%
df[df.name.isna()]
# Out:
# Empty DataFrame
# Columns: [ident, type, name, elevation_ft, continent, iso_country, iso_region, municipality, gps_code, iata_code, local_code, coordinates]
# Index: []

# %%
df.to_csv('airports_simplified.csv')

# %%
df.head()
# Out:
#                  type                           name iso_country iata_code
# 6187   medium_airport        Aleknagik / New Airport          US       WKK
# 10435  medium_airport  Honiara International Airport          SB       HIR
# 10440  medium_airport                  Munda Airport          SB       MUA
# 10462  medium_airport               Hongyuan Airport          CN       AHJ
# 10686  medium_airport    Nauru International Airport          NR       INU

# %%
df = pd.read_csv('airports.csv')

# %%
df[df['name'].str.contains('parque')]
# Out:
#          ident           type                       name  elevation_ft  \
# 10792  AR-0038  small_airport  Alvear Aeroparque Airport          85.0
# 34526  MX-0319       heliport  Hotel Tecnoparque Helipad        7477.0
#
#       continent iso_country iso_region  municipality gps_code iata_code  \
# 10792        SA          AR       AR-S        Alvear      NaN       NaN
# 34526       NaN          MX     MX-DIF  Azcapotzalco      NaN       NaN
#
#       local_code            coordinates
# 10792        AVA     -33.0467, -60.5969
# 34526        HTN  19.505984, -99.179256

# %%
df[df['iata_code'] == 'AEP']
# Out:
#       ident            type                   name  elevation_ft continent  \
# 40830  SABE  medium_airport  Jorge Newbery Airpark          18.0        SA
#
#       iso_country iso_region  municipality gps_code iata_code local_code  \
# 40830          AR       AR-C  Buenos Aires     SABE       AEP        AER
#
#               coordinates
# 40830  -34.5592, -58.4156

# %%
df.head()
# Out:
#      ident           type                     name  elevation_ft continent  \
# 223    03N  small_airport           Utirik Airport           4.0        OC
# 440   07FA  small_airport  Ocean Reef Club Airport           8.0       NaN
# 594    0AK  small_airport    Pilot Station Airport         305.0       NaN
# 673   0CO2  small_airport    Crested Butte Airpark        8980.0       NaN
# 1088  0TE7  small_airport        LBJ Ranch Airport        1515.0       NaN
#
#      iso_country iso_region   municipality gps_code iata_code local_code  \
# 223           MH     MH-UTI  Utirik Island     K03N       UTK        03N
# 440           US      US-FL      Key Largo     07FA       OCA       07FA
# 594           US      US-AK  Pilot Station      NaN       PQS        0AK
# 673           US      US-CO  Crested Butte     0CO2       CSE       0CO2
# 1088          US      US-TX   Johnson City     0TE7       JCY       0TE7
#
#                                  coordinates
# ...

# %%
df.drop()
